# %%
import time
import numpy as np
import pandas as pd
from tqdm import tqdm

from bs4 import BeautifulSoup
from selenium import webdriver

# %%
df = pd.read_csv('data.csv')

df.head()
# Out:
#                                                title       views   date_time  \
# 0  Lecture-4 | Sorting an ARRAY | FREE Premium Le...   200 views  1 hour ago
# 1  Lecture-3 | Sorting in Java | FREE Premium Lec...   890 views  2 days ago
# 2  Lecture-2 | Sorting in CPP | FREE Premium Lect...   903 views  4 days ago
# 3  7 Game-Changing Productivity Tools You Need to...    1K views  4 days ago
# 4  Lecture-1 | Intro to Sorting Algorithms | FREE...  2.7K views  4 days ago
#
#                                      video_link  \
# 0  https://www.youtube.com//watch?v=6mwz4JQ6Z50
# 1  https://www.youtube.com//watch?v=mUX5IfNwhjg
# 2  https://www.youtube.com//watch?v=tmESfVUaTog
# 3  https://www.youtube.com//watch?v=gH-7ezHeuEo
# 4  https://www.youtube.com//watch?v=cqBW7BgN7Zs
#
#                                      thumbnail_link
# 0  https://i.ytimg.com/vi/6mwz4JQ6Z50/hqdefault.jpg
# 1  https://i.ytimg.com/vi/mUX5IfNwhjg/hqdefault.jpg
# 2  https://i.ytimg.com/vi/tmESfVUaTog/hqdefault.jpg
# 3  https://i.ytimg.com/vi/gH-7ezHeuEo/hqdefault.jpg
# 4  https://i.ytimg.com/vi/cqBW7BgN7Zs/hqdefault.jpg

# %%
browser = webdriver.Chrome()
browser.get('https://www.youtube.com')
time.sleep(2)

data = []
 
for link in tqdm(df['video_link']):
    browser.get(link)
    time.sleep(5)
    soup = BeautifulSoup(browser.page_source, 'html.parser')

    try:
        title = soup.find_all('yt-formatted-string', class_ = 'style-scope ytd-video-primary-info-renderer')[0].text
    except:
        title = np.nan
    try:
        view = soup.find('span' , class_ = 'view-count style-scope ytd-video-view-count-renderer').text
    except:
        view = np.nan
    try:
        date_time = soup.find_all('yt-formatted-string', class_ = 'style-scope ytd-video-primary-info-renderer')[1].text
    except:
        date_time = np.nan
    try:
        like = soup.find('button', class_ = 'yt-spec-button-shape-next yt-spec-button-shape-next--tonal yt-spec-button-shape-next--mono yt-spec-button-shape-next--size-m yt-spec-button-shape-next--icon-leading yt-spec-button-shape-next--segmented-start').get('aria-label').split()[5]
    except:
        like = np.nan
    try:
        description = soup.find('span',class_ = 'yt-core-attributed-string yt-core-attributed-string--white-space-pre-wrap')
    except:
        description = np.nan
    data.append([title , date_time, like, view, link, description])
# Out:
# 100%|██████████| 60/60 [06:55<00:00,  6.92s/it]

# %%
#Creating and Saving the dataframe
df = pd.DataFrame(data, columns = ['title' , 'date_time', 'likes', 'views', 'link' , 'description'])

# %%
df.head()
# Out:
#                                                title     date_time likes  \
# 0  Lecture-4 | Sorting an ARRAY | FREE Premium Le...  Jun 15, 2024    17
# 1  Lecture-3 | Sorting in Java | FREE Premium Lec...  Jun 13, 2024    32
# 2  Lecture-2 | Sorting in CPP | FREE Premium Lect...  Jun 11, 2024    28
# 3  7 Game-Changing Productivity Tools You Need to...  Jun 11, 2024    69
# 4  Lecture-1 | Intro to Sorting Algorithms | FREE...  Jun 10, 2024    87
#
#          views                                          link  \
# 0    408 views  https://www.youtube.com//watch?v=6mwz4JQ6Z50
# 1    906 views  https://www.youtube.com//watch?v=mUX5IfNwhjg
# 2    910 views  https://www.youtube.com//watch?v=tmESfVUaTog
# 3  1,104 views  https://www.youtube.com//watch?v=gH-7ezHeuEo
# 4  2,791 views  https://www.youtube.com//watch?v=cqBW7BgN7Zs
#
#                                          description
# 0  [[Level Up Your Coding: Sorting Mastery in Arr...
# 1  [[Level Up Your Coding: Sorting Mastery in Jav...
# 2  [[Welcome to Lecture-2 of our Sorting Playlist...
# 3  [[7 Game-Changing Productivity Tools You Need ...
# 4  [[Get started with Sorting algorithms with the...

# %%
df.to_csv('GFG.csv', index = False)
